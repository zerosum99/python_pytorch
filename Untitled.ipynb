# %%
# !conda create -y --name pytorch-nlp python=3.6 numpy pyyaml scipy ipython mkl tqdm
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.8
#   latest version: 4.5.10
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/dahlmoon/anaconda/envs/pytorch-nlp
#
#   added / updated specs:
#     - ipython
#     - mkl
#     - numpy
#     - python=3.6
#     - pyyaml
#     - scipy
#     - tqdm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ptyprocess-0.6.0           |           py36_0          23 KB
#     blas-1.0                   |              mkl           5 KB
#     mkl_random-1.0.1           |   py36h5d10147_1         349 KB
#     mkl_fft-1.0.4              |   py36h5d10147_1         137 KB
#     ipython-6.5.0              |           py36_0         1.0 MB
# ...

# %%
# !conda install -y conda
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/dahlmoon/anaconda
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.5.10               |           py36_0         1.0 MB
#
# The following packages will be UPDATED:
#
#     certifi: 2018.4.16-py36_0  --> 2018.8.13-py36_0
#     conda:   4.5.8-py36_0      --> 4.5.10-py36_0
#     openssl: 1.0.2o-h26aff7b_0 --> 1.0.2p-h1de35cc_0
#
# Proceed ([y]/n)?
